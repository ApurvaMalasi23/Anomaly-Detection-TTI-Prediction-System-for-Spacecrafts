# %%
# 1. Mount Drive and load preprocessed data
from google.colab import drive
import os
import numpy as np

drive.mount('/content/drive')

BASE_DIR = '/content/drive/MyDrive/spacecraft_anomaly_project'
PROCESSED_DIR = os.path.join(BASE_DIR, 'data', 'processed')

X = np.load(os.path.join(PROCESSED_DIR, 'X_windows.npy'))
y = np.load(os.path.join(PROCESSED_DIR, 'y_windows.npy'))  # Only for evaluation

print(f"X shape: {X.shape} | y shape: {y.shape}")
# Out:
# Mounted at /content/drive
# X shape: (2094, 30, 21) | y shape: (2094,)

# %%
# Only use normal windows for training
X_train = X[y == 0]
print(f"Training on {X_train.shape[0]} normal windows")
# Out:
# Training on 365 normal windows

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.losses import MeanSquaredError

timesteps = X.shape[1]
n_features = X.shape[2]

def build_lstm_autoencoder(timesteps, n_features):
    input_layer = layers.Input(shape=(timesteps, n_features))

    # Encoder
    x = layers.LSTM(64, return_sequences=True)(input_layer)
    x = layers.LSTM(32, return_sequences=False)(x)

    # Bottleneck
    x = layers.RepeatVector(timesteps)(x)

    # Decoder
    x = layers.LSTM(32, return_sequences=True)(x)
    x = layers.LSTM(64, return_sequences=True)(x)
    output_layer = layers.TimeDistributed(layers.Dense(n_features))(x)

    model = models.Model(inputs=input_layer, outputs=output_layer)
    model.compile(optimizer='adam', loss=MeanSquaredError())
    return model

model = build_lstm_autoencoder(timesteps, n_features)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 30, 21)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 30, 64)         │        22,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_1 (RepeatVector)  │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 30, 32)         │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 30, 64)         │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 30, 21)         │         1,365 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,949 (269.33 KB)
#  Trainable params: 68,949 (269.33 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)

history = model.fit(
    X_train, X_train,
    epochs=50,
    batch_size=64,
    validation_split=0.1,
    callbacks=[early_stop],
    shuffle=True
)
# Out:
# Epoch 1/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 377ms/step - loss: 0.7039 - val_loss: 0.3749
# Epoch 2/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.4991 - val_loss: 0.2503
# Epoch 3/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.3893 - val_loss: 0.2056
# Epoch 4/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.3230 - val_loss: 0.1849
# Epoch 5/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.2999 - val_loss: 0.1815
# Epoch 6/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.2978 - val_loss: 0.1724
# Epoch 7/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.2738 - val_loss: 0.1669
# Epoch 8/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.2717 - val_loss: 0.1633
# Epoch 9/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.2527 - val_loss: 0.1607
# Epoch 10/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - loss: 0.2486 - val_loss: 0.1595
# Epoch 11/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.2349 - val_loss: 0.1580
# Epoch 12/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 0.2456 - val_loss: 0.1575
# Epoch 13/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.2309 - val_loss: 0.1543
# Epoch 14/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.2180 - val_loss: 0.1512
# Epoch 15/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.2157 - val_loss: 0.1549
# Epoch 16/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.2116 - val_loss: 0.1557
# Epoch 17/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.1890 - val_loss: 0.1509
# Epoch 18/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.2049 - val_loss: 0.1505
# Epoch 19/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.1949 - val_loss: 0.1494
# Epoch 20/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.1775 - val_loss: 0.1457
# Epoch 21/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.1766 - val_loss: 0.1479
# Epoch 22/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1741 - val_loss: 0.1479
# Epoch 23/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.1633 - val_loss: 0.1453
# Epoch 24/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.1631 - val_loss: 0.1447
# Epoch 25/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.1664 - val_loss: 0.1436
# Epoch 26/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.1604 - val_loss: 0.1419
# Epoch 27/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.1638 - val_loss: 0.1418
# Epoch 28/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.1681 - val_loss: 0.1424
# Epoch 29/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.1535 - val_loss: 0.1417
# Epoch 30/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1495 - val_loss: 0.1400
# Epoch 31/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 0.1491 - val_loss: 0.1412
# Epoch 32/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.1513 - val_loss: 0.1381
# Epoch 33/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.1453 - val_loss: 0.1400
# Epoch 34/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.1449 - val_loss: 0.1380
# Epoch 35/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.1423 - val_loss: 0.1392
# Epoch 36/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.1434 - val_loss: 0.1405
# Epoch 37/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.1547 - val_loss: 0.1363
# Epoch 38/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.1377 - val_loss: 0.1368
# Epoch 39/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.1405 - val_loss: 0.1371
# Epoch 40/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.1386 - val_loss: 0.1384
# Epoch 41/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1364 - val_loss: 0.1371
# Epoch 42/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.1397 - val_loss: 0.1357
# Epoch 43/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1437 - val_loss: 0.1350
# Epoch 44/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.1353 - val_loss: 0.1373
# Epoch 45/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.1336 - val_loss: 0.1380
# Epoch 46/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.1348 - val_loss: 0.1367
# Epoch 47/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.1384 - val_loss: 0.1363
# Epoch 48/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.1337 - val_loss: 0.1340
# Epoch 49/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.1565 - val_loss: 0.1384
# Epoch 50/50
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.1676 - val_loss: 0.1352

# %%
MODEL_DIR = os.path.join(BASE_DIR, 'models', 'autoencoder')
os.makedirs(MODEL_DIR, exist_ok=True)

model.save(os.path.join(MODEL_DIR, 'lstm_autoencoder.h5'))
print("✅ Model saved.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved.
